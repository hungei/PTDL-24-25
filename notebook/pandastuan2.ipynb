# %% [markdown]
# BÀI TẬP TUẦN 2 PANDAS - lÊ QUỐC HƯNG - 22712771

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
#1. đọc file  với file  trong thư mục dữ liệu . ứng với mỗi file sinh  viên thực hiện  cá câu sau
df = pd.read_csv("orginal_sales_data_edit.csv")
df.head(5) # in 5 dòng đầu
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
# đọc 5 dòng cuối 
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2818  12/2/2004   Shipped       4        12     2004  ...          NaN
# 2819  1/31/2005   Shipped       1         1     2005  ...          NaN
# 2820   3/1/2005  Resolved       1         3     2005  ...          NaN
# 2821  3/28/2005   Shipped       1         3     2005  ...          NaN
# 2822   5/6/2005   On Hold       2         5     2005  ...          NaN
#
#           CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
# chuyển  kiểu dữ liệu  cho 1 cột nào đó
df['YEAR_ID']= df['YEAR_ID'].astype('int32')
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
# xem chiều dài df tương đương shape[0]
print('len :',len(df))
# Out:
# len : 2823

# %%
#xem thông tin df vừa đọc được
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int32
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CATEGORY          2823 non-null   object
#  14  SUBCATEGORY       2823 non-null   object
#  15  CUSTOMERNAME      2823 non-null   object
# ...

# %%
# xem kích thước df
print("shape: ", df.shape)
# Out:
# shape:  (2823, 28)

# %%
#hiển thị dữ liệu cột 10
df['PRODUCTLINE']
# Out:
# 0       Motorcycles
# 1       Motorcycles
# 2       Motorcycles
# 3       Motorcycles
# 4       Motorcycles
#            ...
# 2818          Ships
# 2819          Ships
# 2820          Ships
# 2821          Ships
# 2822          Ships
# Name: PRODUCTLINE, Length: 2823, dtype: object

# %%
# HIỂN THIj dữ liệu cột 1,2,3,5,6
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','SALES','ORDERDATE' ]]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE
# 0           10107               30      95.70  2871.00   2/24/2003
# 1           10121               34      81.35  2765.90    5/7/2003
# 2           10134               41      94.74  3884.34    7/1/2003
# 3           10145               45      83.26  3746.70   8/25/2003
# 4           10159               49     100.00  5205.27  10/10/2003
# ...           ...              ...        ...      ...         ...
# 2818        10350               20     100.00  2244.40   12/2/2004
# 2819        10373               29     100.00  3978.51   1/31/2005
# 2820        10386               43     100.00  5417.57    3/1/2005
# 2821        10397               34      62.24  2116.16   3/28/2005
# 2822        10414               47      65.52  3079.44    5/6/2005
#
# [2823 rows x 5 columns]

# %%
#hiển thị 5 dòng đàu tiên của cột 12356
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','SALES','ORDERDATE' ]].head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE
# 0        10107               30      95.70  2871.00   2/24/2003
# 1        10121               34      81.35  2765.90    5/7/2003
# 2        10134               41      94.74  3884.34    7/1/2003
# 3        10145               45      83.26  3746.70   8/25/2003
# 4        10159               49     100.00  5205.27  10/10/2003

# %%
#hiển thị 5 dòng đầu tiên theo chỉ số
df[0:5]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
#hiển thị 5 dòng dữ liệu đầu tiên theo chri số gồm các cột 1,2,3,5,6
df[['ORDERNUMBER','QUANTITYORDERED','PRICEEACH','SALES','ORDERDATE' ]][:5]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE
# 0        10107               30      95.70  2871.00   2/24/2003
# 1        10121               34      81.35  2765.90    5/7/2003
# 2        10134               41      94.74  3884.34    7/1/2003
# 3        10145               45      83.26  3746.70   8/25/2003
# 4        10159               49     100.00  5205.27  10/10/2003

# %%
# loại bỏ  các dòng trung nhau
df.drop_duplicates(inplace=True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# loại bỏ các dòng  trống có dữ liệu là cột rỗng , có 2823 dòng
df['ADDRESSLINE2'].isna().sum() #còn 2521 dòng
# Out:
# 2521

# %%
#loại bỏ dòng của một cột có giá trị là unknown, có 2521 dòng
df['ADDRESSLINE2'].fillna('Unknown',inplace=True)
df['ADDRESSLINE2'].isna().sum()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# lấy dữ liệu của 1 cột theo dạng chuỗi 
df['QUANTITYORDERED']
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %%
#lấy dữ liệu một cột theo dạng mảng
df['QUANTITYORDERED'].values
# Out:
# array([30, 34, 41, ..., 43, 34, 47], dtype=int64)

# %%
#lây dữ liệu từ dòng 4 đến dòng 9
df[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4  10/10/2003  Shipped       4        10     2003  ...      Unknown
# 5  10/28/2003  Shipped       4        10     2003  ...      Unknown
# 6  11/11/2003  Shipped       4        11     2003  ...      Unknown
# 7  11/18/2003  Shipped       4        11     2003  ...      Unknown
# 8   12/1/2003  Shipped       4        12     2003  ...      Unknown
# 9   1/15/2004  Shipped       1         1     2004  ...      Unknown
#
# ...

# %%
#đọc dữ liệu từ dòng 4 đến dòng 9
df.loc[4:10]
df.iloc[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4  10/10/2003  Shipped       4        10     2003  ...      Unknown
# 5  10/28/2003  Shipped       4        10     2003  ...      Unknown
# 6  11/11/2003  Shipped       4        11     2003  ...      Unknown
# 7  11/18/2003  Shipped       4        11     2003  ...      Unknown
# 8   12/1/2003  Shipped       4        12     2003  ...      Unknown
# 9   1/15/2004  Shipped       1         1     2004  ...      Unknown
#
# ...

# %%
#lấy thông tin tại dòng có chỉ số là 2
df.loc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                              Unknown
# ...

# %%
#lấy thông tin của dòng 4 đến dòng 10 của một số cột
df.loc[4:10,['QUANTITYORDERED','SALES']]
# Out:
#     QUANTITYORDERED    SALES
# 4                49  5205.27
# 5                36  3479.76
# 6                29  2497.77
# 7                48  5512.32
# 8                22  2168.54
# 9                41  4708.44
# 10               37  3965.66

# %%
#lấy thông tin từ dòng 2 đến 9 ,cột 4 đến 7
df.iloc[2:9,4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped

# %%
#lấy dữ liệu tại chỉ số index =2 
df.iloc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                              Unknown
# ...

# %%
#lấy dữ liệu từ dòng đầu tiên đến dòng 9
df.iloc[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...      Unknown
# 1    5/7/2003  Shipped       2         5     2003  ...      Unknown
# ...

# %%
# lấy dữ liệu dòng đầu tiên đến dòng 9 gồn cột 4 đến 7
df.iloc[:10,4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 0  2871.00   2/24/2003  Shipped
# 1  2765.90    5/7/2003  Shipped
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped
# 9  4708.44   1/15/2004  Shipped

# %%
# sắp xếp dữ liệu theo sales tăng dần
df.sort_values(by='SALES',ascending=True)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2249        10425               11      43.83                6    482.13
# 1287        10407                6      90.19                3    541.14
# 2044        10408               15      36.93                1    553.95
# 1551        10280               20      28.88               12    577.60
# 1818        10419               15      42.67                7    640.05
# ...           ...              ...        ...              ...       ...
# 104         10403               66     100.00                9  11886.60
# 1062        10412               60     100.00                9  11887.80
# 53          10424               50     100.00                6  12001.00
# 744         10322               50     100.00                6  12536.50
# 598         10407               76     100.00                2  14082.80
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#sắp xếp dữ liệu theo nhiều tiêu chí
df.sort_values(by=['QUANTITYORDERED','PRICEEACH'], ascending=[True,False])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 751         10409                6     100.00                2    785.64
# 1287        10407                6      90.19                3    541.14
# 315         10419               10     100.00               11   1092.20
# 907         10423               10      88.14                1    881.40
# 2507        10401               11     100.00                8   1135.31
# ...           ...              ...        ...              ...       ...
# 1995        10405               76     100.00                3  11739.70
# 1714        10407               76      94.50                6   7182.00
# 2689        10401               77      92.00                9   7084.00
# 2586        10401               85      88.75               10   7543.75
# 418         10405               97      93.28                5   9048.16
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# lọc dữ liêu theo điều kiện
df[df['SALES']>5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#cách 2 
df.loc[df['SALES']>5000]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4           10159               49      100.0               14  5205.27
# 7           10188               48      100.0                1  5512.32
# 20          10341               41      100.0                9  7737.93
# 25          10417               66      100.0                2  7516.08
# 26          10103               26      100.0               11  5404.62
# ...           ...              ...        ...              ...      ...
# 2685        10361               44      100.0               10  5001.92
# 2686        10375               44      100.0               11  5208.72
# 2689        10401               77       92.0                9  7084.00
# 2715        10397               48      100.0                3  5192.64
# 2820        10386               43      100.0                4  5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#lọc dữ liệu theo nhiều điều kiện
df[(df['SALES']>5000) & (df['QUANTITYORDERED']>40)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 4           10159               49      100.0               14   5205.27
# 7           10188               48      100.0                1   5512.32
# 20          10341               41      100.0                9   7737.93
# 25          10417               66      100.0                2   7516.08
# 30          10150               45      100.0                8  10993.50
# ...           ...              ...        ...              ...       ...
# 2685        10361               44      100.0               10   5001.92
# 2686        10375               44      100.0               11   5208.72
# 2689        10401               77       92.0                9   7084.00
# 2715        10397               48      100.0                3   5192.64
# 2820        10386               43      100.0                4   5417.57
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#LỌC  giá trị và gán  điều kiện dùng loc
df.loc[df['PRICEEACH']>=65,'FLAG']='EXPENSIVE'
df.loc[df['PRICEEACH']<=65,'FLAG'] = 'CHEAP'
df['FLAG']
df[['PRICEEACH','FLAG']][:50]
# Out:
#     PRICEEACH       FLAG
# 0       95.70  EXPENSIVE
# 1       81.35  EXPENSIVE
# 2       94.74  EXPENSIVE
# 3       83.26  EXPENSIVE
# 4      100.00  EXPENSIVE
# 5       96.66  EXPENSIVE
# 6       86.13  EXPENSIVE
# 7      100.00  EXPENSIVE
# 8       98.57  EXPENSIVE
# 9      100.00  EXPENSIVE
# 10     100.00  EXPENSIVE
# 11     100.00  EXPENSIVE
# 12     100.00  EXPENSIVE
# 13     100.00  EXPENSIVE
# 14      92.83  EXPENSIVE
# 15     100.00  EXPENSIVE
# 16     100.00  EXPENSIVE
# 17     100.00  EXPENSIVE
# 18      94.74  EXPENSIVE
# 19     100.00  EXPENSIVE
# 20     100.00  EXPENSIVE
# 21      72.55  EXPENSIVE
# 22      34.91      CHEAP
# 23      76.36  EXPENSIVE
# 24     100.00  EXPENSIVE
# 25     100.00  EXPENSIVE
# 26     100.00  EXPENSIVE
# 27     100.00  EXPENSIVE
# 28     100.00  EXPENSIVE
# 29     100.00  EXPENSIVE
# 30     100.00  EXPENSIVE
# 31     100.00  EXPENSIVE
# 32     100.00  EXPENSIVE
# 33     100.00  EXPENSIVE
# 34     100.00  EXPENSIVE
# 35     100.00  EXPENSIVE
# ...

# %%
# viết hàm trả về giá trị có nhiều điều kiện  và áp dụng hàm gán gí trị trả về cho 1 cột
def foo(x):
    if x<10:
        return 'BAD'
    elif x>=10:
        return 'GOOD'
    else:
        return 'EXCELLENT'
df['WORTH']=df[['QUANTITYORDERED']].applymap(foo)
df[['QUANTITYORDERED','WORTH']]
# Out:
#       QUANTITYORDERED WORTH
# 0                  30  GOOD
# 1                  34  GOOD
# 2                  41  GOOD
# 3                  45  GOOD
# 4                  49  GOOD
# ...               ...   ...
# 2818               20  GOOD
# 2819               29  GOOD
# 2820               43  GOOD
# 2821               34  GOOD
# 2822               47  GOOD
#
# [2823 rows x 2 columns]

# %%
# ánh xạ giá trị tới 1 cột 
dict_map1 = {1:'qui 1',2:'qui 2', 3:'qui 3',4:'qui 4'}
df['QTR_ID']=df['QTR_ID'].map(dict_map1)
df['QTR_ID']
# Out:
# 0       qui 1
# 1       qui 2
# 2       qui 3
# 3       qui 3
# 4       qui 4
#         ...
# 2818    qui 4
# 2819    qui 1
# 2820    qui 1
# 2821    qui 1
# 2822    qui 2
# Name: QTR_ID, Length: 2823, dtype: object

# %%
#lấy những dòng dữ liệu từ bằng 1 điều kiện nào đó
df[['QUANTITYORDERED','PRICEEACH']].loc[df['YEAR_ID']==2003]
# Out:
#       QUANTITYORDERED  PRICEEACH
# 0                  30      95.70
# 1                  34      81.35
# 2                  41      94.74
# 3                  45      83.26
# 4                  49     100.00
# ...               ...        ...
# 2801               50      60.06
# 2802               38      48.59
# 2803               40      50.23
# 2804               28      64.43
# 2805               42      50.23
#
# [1000 rows x 2 columns]

# %%
# hiển thị bản ghi có giá trị lớn hơn 25
df[df['QUANTITYORDERED']>25]
print('hiển thị 5 dòng')
tuoitre=df[df['QUANTITYORDERED']>25]
tuoitre[:5]
# Out:
# hiển thị 5 dòng
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 0   2/24/2003  Shipped  qui 1         2     2003  ...    NY       10022
# 1    5/7/2003  Shipped  qui 2         5     2003  ...   NaN       51100
# 2    7/1/2003  Shipped  qui 3         7     2003  ...   NaN       75508
# 3   8/25/2003  Shipped  qui 3         8     2003  ...    CA       90003
# 4  10/10/2003  Shipped  qui 4        10     2003  ...    CA         NaN
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME  \
# ...

# %%
# hiển thị hóa đơn được giao
dg=df[df['STATUS']=='Shipped']
dg[:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 0   2/24/2003  Shipped  qui 1         2     2003  ...    NY       10022
# ...

# %%
# so sánh chuỗi 
sosanh= df['STATUS'].str.contains('Shipped')
sosanh.head(5)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: STATUS, dtype: bool

# %%
# lấy giá trị về mảng
df['STATUS'].values
# Out:
# array(['Shipped', 'Shipped', 'Shipped', ..., 'Resolved', 'Shipped',
#        'On Hold'], dtype=object)

# %%
# thêm 1 cột vào dữ liệu 
df_len=len(df)
ngaylap=[random.randrange(2003,2005,1) for i in range(df_len)]
df['ORDERDATE']= ngaylap
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 2818       2004   Shipped  qui 4        12     2004  ...   NaN       28034
# 2819       2003   Shipped  qui 1         1     2005  ...   NaN       90110
# 2820       2004  Resolved  qui 1         3     2005  ...   NaN       28034
# 2821       2004   Shipped  qui 1         3     2005  ...   NaN       31000
# 2822       2003   On Hold  qui 2         5     2005  ...    MA       51003
#
#       COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# ...

# %%
# thêm 1 cột đang giao vào  dữ liệu theo tiêu chí nếu điều kiện thỏa thì giá trị mặc định là true, ngược lại là false
df['DaGiao'] = df['STATUS'] =='Shipped'
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... POSTALCODE  COUNTRY  \
# 0       2004  Shipped  qui 1         2     2003  ...      10022      USA
# 1       2003  Shipped  qui 2         5     2003  ...      51100   France
# 2       2003  Shipped  qui 3         7     2003  ...      75508   France
# 3       2003  Shipped  qui 3         8     2003  ...      90003      USA
# 4       2003  Shipped  qui 4        10     2003  ...        NaN      USA
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME  \
# ...

# %%
# tạo cột mới có giá trị rỗng
df['TONGTIEN']=None
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ...  COUNTRY  TERRITORY  \
# ...

# %%
#sửa giá trị của cột 
df['QTR_ID']= None
df['QTR_ID']='Quy '
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... COUNTRY  TERRITORY  \
# 0       2004  Shipped   Quy          2     2003  ...     USA        NaN
# 1       2003  Shipped   Quy          5     2003  ...  France       EMEA
# 2       2003  Shipped   Quy          7     2003  ...  France       EMEA
# 3       2003  Shipped   Quy          8     2003  ...     USA        NaN
# 4       2003  Shipped   Quy         10     2003  ...     USA        NaN
#
#   CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME       FLAG WORTH  \
# ...

# %%
#xóa cột trong df
df.drop(['TONGTIEN'],axis=1)
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... COUNTRY  TERRITORY  \
# 0       2004  Shipped   Quy          2     2003  ...     USA        NaN
# 1       2003  Shipped   Quy          5     2003  ...  France       EMEA
# 2       2003  Shipped   Quy          7     2003  ...  France       EMEA
# 3       2003  Shipped   Quy          8     2003  ...     USA        NaN
# 4       2003  Shipped   Quy         10     2003  ...     USA        NaN
#
#   CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME       FLAG WORTH  \
# ...

# %%
#xóa bản ghi theo chỉ sô
df.drop([0,1]) #xóa bản ghi có chỉ số 1 và 2
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 6           10180               29      86.13                9  2497.77
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ...  COUNTRY  TERRITORY  \
# ...

# %%
# sử dụng hàm describe để thống kê dữ liệuk
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES    ORDERDATE     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072  2003.507616     7.092455  2003.81509   100.715551
# std     1841.865106     0.500031     3.656633     0.69967    40.187912
# min      482.130000  2003.000000     1.000000  2003.00000    33.000000
# ...

# %%
#xem thống kê trên từng cột
df['STATUS'].value_counts()
# Out:
# Shipped       2617
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: STATUS, dtype: int64

# %%
#vẽ đồ thị xem phân bố giá trị của 1 tường trong df
df['STATUS'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
#tạo df từ python list
peoples={'name':['nguyễn văn hiếu','hiếu nguyễn văn'], 'age': [28,38], 'website': ['https://blog.luyencode.net',None]}
df1= pd.DataFrame(peoples)
print(df1)
# Out:
#               name  age                     website
# 0  nguyễn văn hiếu   28  https://blog.luyencode.net
# 1  hiếu nguyễn văn   38                        None

# %%
# tạo mới df từ python list 
txts =  ['chỗ này ăn khá ngon','ngon, nhất định sẽ quay lại','thái độ phục vụ quá tệ']
labels = [1,1,0]
df1=pd.DataFrame()
df1['txt']= txts
df1['label']= labels
print(df1)
# Out:
#                            txt  label
# 0          chỗ này ăn khá ngon      1
# 1  ngon, nhất định sẽ quay lại      1
# 2       thái độ phục vụ quá tệ      0

# %%
#sắp xếp df
# sắp xếp df tăng dần 
df1 = pd.DataFrame({'name': ['Nam','hiếu', 'mai', 'hoa'],'age':[18,18,17,19]})
print('Before sort\n',df1)
df1=df1.sort_values('age',ascending=True)
print('after sorf\n',df1)
# Out:
# Before sort
#     name  age
# 0   Nam   18
# 1  hiếu   18
# 2   mai   17
# 3   hoa   19
# after sorf
#     name  age
# 2   mai   17
# 0   Nam   18
# 1  hiếu   18
# 3   hoa   19

# %%
# nối df
#gộp df
df_1= pd.DataFrame({'name': ['hiếu'], 'age': [18], 'gender': ['male']})
df_2= pd.DataFrame({'name': ['nam','mai','hoa'], 'age': [15,17,19]})
df_3= df_1.append(df_2,sort=True)
print(df_3)
# Out:
#    age gender  name
# 0   18   male  hiếu
# 0   15    NaN   nam
# 1   17    NaN   mai
# 2   19    NaN   hoa
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6352\1531563904.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_3= df_1.append(df_2,sort=True)

# %%
# xáo trộn bản ghi trong df
df1= pd.DataFrame({'name': ['nam','mai','hoa'], 'age': [15,17,19]})
print('beofore shuffle\n',df1)
df1 = df1.sample(frac=1).reset_index(drop=True)
print('after shuffle\n',df1)
# Out:
# beofore shuffle
#    name  age
# 0  nam   15
# 1  mai   17
# 2  hoa   19
# after shuffle
#    name  age
# 0  mai   17
# 1  hoa   19
# 2  nam   15

# %%
#55. Tối ưu bộ nhớ khi dùng pandas
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


def reduce_mem_usage(df):
    """
    iterate through all the columns of a dataframe and modify the data type
    to reduce memory usage.
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage of dataframe is: {:.2f} MB".format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype

        if col_type != object and col_type.name != 'category' and 'datetime' not in col_type.name:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
        elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                
    end_mem = df.memory_usage().sum() / 1024**2
    print("Memory usage after optimization is: {:.2f} MB".format(end_mem))
    print("Decreased by {:.1f}%".format(100 * (start_mem - end_mem) / start_mem))

    return df
